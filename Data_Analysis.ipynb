# %% [markdown]
# # Data Analysis

# %% [markdown]
# ### Standard imports and loading data

# %%
import pandas as pd
import numpy as np
from PayneLabData import BurkholderiaTimeCourse as btc
from bokeh.io import output_notebook, show
from bokeh.plotting import figure
from bokeh.layouts import row, column
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="3fece0a8-d94f-4cf0-8858-c2fded2e15b7">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ## B_thai No Glucose Analysis

# %%
bthai = btc.bthai_raw

# %% [markdown]
# ### Find standard biological variability by using the standard deviations of each time point

# %%
bthai_stdev = pd.DataFrame()
bthai_stdev['tp1'] = bthai[['Glc(-)_T11', 'Glc(-)_T12', 'Glc(-)_T13', 'Glc(-)_T14']].std(axis=1)
bthai_stdev['tp2'] = bthai[['Glc(-)_T21', 'Glc(-)_T22', 'Glc(-)_T23', 'Glc(-)_T24']].std(axis=1)
bthai_stdev['tp3'] = bthai[['Glc(-)_T31', 'Glc(-)_T32', 'Glc(-)_T33', 'Glc(-)_T34']].std(axis=1)
bthai_stdev['tp4'] = bthai[['Glc(-)_T41', 'Glc(-)_T42', 'Glc(-)_T43', 'Glc(-)_T44']].std(axis=1)
bthai_stdev['tp5'] = bthai[['Glc(-)_T51', 'Glc(-)_T52', 'Glc(-)_T53', 'Glc(-)_T54']].std(axis=1)
bthai_stdev = bthai_stdev.dropna(axis = 0)

# %%
# Histogram for time point 1
tp1_std_hist, edges = np.histogram(bthai_stdev['tp1'], density=True, bins=100)
tp1_std_p = figure(width=350, plot_height=350, title = 'Standard Deviations at Time Point 1',
                  x_axis_label = 'Standard Deviation',
                  y_axis_label = 'Number of Proteins')
tp1_std_p.quad(top=tp1_std_hist, bottom=0, left=edges[:-1], right=edges[1:], color = 'navy')

# Histogram for time point 2
tp2_std_hist, edges = np.histogram(bthai_stdev['tp2'], density=True, bins=100)
tp2_std_p = figure(width=350, plot_height=350, title = 'Standard Deviations at Time Point 2',
                  x_axis_label = 'Standard Deviation',
                  y_axis_label = 'Number of Proteins')
tp2_std_p.quad(top=tp2_std_hist, bottom=0, left=edges[:-1], right=edges[1:])

# Histogram for time point 3
tp3_std_hist, edges = np.histogram(bthai_stdev['tp3'], density=True, bins=100)
tp3_std_p = figure(width=350, plot_height=350, title = 'Standard Deviations at Time Point 3',
                  x_axis_label = 'Standard Deviation',
                  y_axis_label = 'Number of Proteins')
tp3_std_p.quad(top=tp3_std_hist, bottom=0, left=edges[:-1], right=edges[1:], color = 'black')

# Histogram for time point 4
tp4_std_hist, edges = np.histogram(bthai_stdev['tp4'], density=True, bins=100)
tp4_std_p = figure(width=350, plot_height=350, title = 'Standard Deviations at Time Point 4',
                  x_axis_label = 'Standard Deviation',
                  y_axis_label = 'Number of Proteins')
tp4_std_p.quad(top=tp4_std_hist, bottom=0, left=edges[:-1], right=edges[1:], color = 'purple')

# Histogram for time point 5
tp5_std_hist, edges = np.histogram(bthai_stdev['tp5'], density=True, bins=100)
tp5_std_p = figure(width=350, plot_height=350, title = 'Standard Deviations at Time Point 5',
                  x_axis_label = 'Standard Deviation',
                  y_axis_label = 'Number of Proteins')
tp5_std_p.quad(top=tp5_std_hist, bottom=0, left=edges[:-1], right=edges[1:], color = 'green')

show(column(row(tp1_std_p, tp2_std_p), row(tp3_std_p, tp4_std_p), row(tp5_std_p)))
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="7c6aee3e-1b0d-43bc-8372-a092ba18e712"></div>
# </div>
